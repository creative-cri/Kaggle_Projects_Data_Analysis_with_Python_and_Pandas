# %% [markdown]
# # Minimum Wage by State - Groupby - Data Analysis with Python 3 and Pandas

# %%
#https://www.kaggle.com/datasets/lislejoem/us-minimum-wage-by-state-from-1968-to-2017

# %%
import pandas as pd

# %%
df = pd.read_csv('Minimum Wage Data.csv', encoding='latin')
df
# Out:
#       Unnamed: 0  Year          State  State.Minimum.Wage  \
# 0              0  1968        Alabama             0.00000
# 1              1  1968         Alaska             2.10000
# 2              2  1968        Arizona             0.46800
# 3              3  1968       Arkansas             0.15625
# 4              4  1968     California             1.65000
# ...          ...   ...            ...                 ...
# 2857        2857  2020       Virginia             7.25000
# 2858        2858  2020     Washington            13.50000
# 2859        2859  2020  West Virginia             8.75000
# 2860        2860  2020      Wisconsin             7.25000
# 2861        2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...                               ...                   ...
# 2857                             7.25                  7.25
# 2858                            13.50                  7.25
# 2859                             8.75                  7.25
# 2860                             7.25                  7.25
# 2861                             5.15                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                  8.55                    1.15
# 1                                  8.55                    2.10
# 2                                  8.55                    1.15
# 3                                  8.55                    1.15
# 4                                  8.55                    1.65
# ...                                 ...                     ...
# 2857                               7.25                    7.25
# 2858                               7.25                   13.50
# 2859                               7.25                    8.75
# 2860                               7.25                    7.25
# 2861                               7.25                    7.25
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                    8.55        34.80
# 1                                   15.61        34.80
# 2                                    8.55        34.80
# 3                                    8.55        34.80
# 4                                   12.26        34.80
# ...                                   ...          ...
# 2857                                 7.25       258.66
# 2858                                13.50       258.66
# 2859                                 8.75       258.66
# 2860                                 7.25       258.66
# 2861                                 7.25       258.66
#
#      Department.Of.Labor.Uncleaned.Data  \
# 0                                   ...
# 1                                   2.1
# 2                   18.72 - 26.40/wk(b)
# 3                           1.25/day(b)
# 4                               1.65(b)
# ...                                 ...
# 2857                            7.25[c]
# 2858                               13.5
# 2859                               8.75
# 2860                               7.25
# 2861                               5.15
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# 0                                   0.00000
# 1                                   2.10000
# 2                                   0.46800
# 3                                   0.15625
# 4                                   1.65000
# ...                                     ...
# 2857                                7.25000
# 2858                               13.50000
# 2859                                8.75000
# 2860                                7.25000
# 2861                                5.15000
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.00
# 1                                                 15.61
# 2                                                  3.48
# 3                                                  1.16
# 4                                                 12.26
# ...                                                 ...
# 2857                                               7.25
# 2858                                              13.50
# 2859                                               8.75
# 2860                                               7.25
# 2861                                               5.15
#
#       Department.Of.Labor.Cleaned.High.Value  \
# 0                                    0.00000
# 1                                    2.10000
# 2                                    0.66000
# 3                                    0.15625
# 4                                    1.65000
# ...                                      ...
# 2857                                 7.25000
# 2858                                13.50000
# 2859                                 8.75000
# 2860                                 7.25000
# 2861                                 5.15000
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.00        NaN
# 1                                                 15.61        NaN
# 2                                                  4.91        (b)
# 3                                                  1.16        (b)
# 4                                                 12.26        (b)
# ...                                                 ...        ...
# 2857                                               7.25        [c]
# 2858                                              13.50        NaN
# 2859                                               8.75        NaN
# 2860                                               7.25        NaN
# 2861                                               5.15        NaN
#
# [2862 rows x 16 columns]

# %%
df.to_csv('Minimum Wage Data.csv', encoding='utf-8')

# %%
df = pd.read_csv('Minimum Wage Data.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Year       State  State.Minimum.Wage  \
# 0           0             0  1968     Alabama             0.00000
# 1           1             1  1968      Alaska             2.10000
# 2           2             2  1968     Arizona             0.46800
# 3           3             3  1968    Arkansas             0.15625
# 4           4             4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# 3                               8.55                    1.15
# 4                               8.55                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                 8.55         34.8
# 1                                15.61         34.8
# 2                                 8.55         34.8
# 3                                 8.55         34.8
# 4                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
gb = df.groupby('State')
gb.get_group('Alabama').set_index('Year').head()
# Out:
#       Unnamed: 0  Unnamed: 0.1    State  State.Minimum.Wage  \
# Year
# 1968           0             0  Alabama                 0.0
# 1969          54            54  Alabama                 0.0
# 1970         108           108  Alabama                 0.0
# 1971         162           162  Alabama                 0.0
# 1972         216           216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# 1971                               8.30                    1.30
# 1972                               9.90                    1.60
#
#       Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# Year
# 1968                                 8.55         34.8
# 1969                                 8.11         36.7
# 1970                                 8.67         38.8
# 1971                                 8.30         40.5
# 1972                                 9.90         41.8
#
#      Department.Of.Labor.Uncleaned.Data  \
# Year
# 1968                                ...
# 1969                                ...
# 1970                                ...
# 1971                                ...
# 1972                                ...
#
#       Department.Of.Labor.Cleaned.Low.Value  \
# Year
# 1968                                    0.0
# 1969                                    0.0
# 1970                                    0.0
# 1971                                    0.0
# 1972                                    0.0
#
#       Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# Year
# 1968                                                0.0
# 1969                                                0.0
# 1970                                                0.0
# 1971                                                0.0
# 1972                                                0.0
#
#       Department.Of.Labor.Cleaned.High.Value  \
# Year
# 1968                                     0.0
# 1969                                     0.0
# 1970                                     0.0
# 1971                                     0.0
# 1972                                     0.0
#
#       Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# Year
# 1968                                                0.0        NaN
# 1969                                                0.0        NaN
# 1970                                                0.0        NaN
# 1971                                                0.0        NaN
# 1972                                                0.0        NaN

# %%
act_min_wage = pd.DataFrame()

# %%
#act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name})

# %%
for name, group in df.groupby("State"):
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name}))

# %%
act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969      0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970      0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971      0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972      0.0   12.99     2.90      7.43       10.21      6.19        11.45
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      9.29                  9.29      0.0  ...        0.0   0.00
# 1969      8.81                  8.81      0.0  ...        0.0   0.00
# 1970      8.33                 10.67      0.0  ...        0.0   0.00
# 1971      7.98                 10.22      0.0  ...        0.0   0.00
# 1972      9.90                  9.90      0.0  ...        0.0   8.66
#
#       U.S. Virgin Islands  Utah  Vermont  Virginia  Washington  West Virginia  \
# Year
# 1968                  NaN  7.43    10.41       0.0       11.89           7.43
# 1969                  NaN  7.05     9.87       0.0       11.28           7.05
# 1970                  NaN  6.67    10.67       0.0       10.67           6.67
# 1971                  NaN  6.39    10.22       0.0       10.22           6.39
# 1972                  NaN  7.43     9.90       0.0        9.90           7.43
#
#       Wisconsin  Wyoming
# Year
# 1968       9.29     8.92
# 1969       8.81     8.46
# 1970       8.67     8.67
# 1971       8.30     8.30
# 1972       8.97     9.28
#
# [5 rows x 54 columns]

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   9.917736   2.917358   7.139245    9.101132   6.881698
# std        0.0   1.852213   4.102247   1.459132    1.418712   1.921086
# min        0.0   7.620000   0.000000   1.100000    6.630000   3.970000
# 25%        0.0   8.590000   0.000000   6.780000    8.000000   5.250000
# 50%        0.0   9.260000   0.000000   7.210000    9.010000   6.670000
# 75%        0.0  10.510000   8.290000   7.740000    9.710000   8.430000
# max        0.0  15.610000  12.140000  10.000000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   7.818679              8.919245   2.415283  ...
# std       1.106907   1.307834              1.932959   3.882305  ...
# min       7.040000   4.550000              5.690000   0.000000  ...
# 25%       8.200000   7.320000              7.420000   0.000000  ...
# 50%       9.430000   8.170000              8.840000   0.000000  ...
# 75%       9.870000   8.620000              9.600000   8.210000  ...
# max      11.450000   9.900000             14.160000   8.790000  ...
#
#        Tennessee      Texas  U.S. Virgin Islands       Utah    Vermont  \
# count       53.0  53.000000            42.000000  53.000000  53.000000
# mean         0.0   5.816038             6.980238   7.079245   9.057358
# std          0.0   2.240879             1.815899   0.824707   1.093119
# min          0.0   0.000000             4.430000   4.950000   7.030000
# 25%          0.0   4.990000             5.225000   6.610000   8.060000
# 50%          0.0   6.360000             7.105000   7.220000   9.240000
# 75%          0.0   7.350000             8.270000   7.660000   9.820000
# max          0.0   8.660000            10.620000   8.600000  11.090000
#
#         Virginia  Washington  West Virginia  Wisconsin    Wyoming
# count  53.000000   53.000000      53.000000  53.000000  53.000000
# mean    6.163019    8.826038       7.486226   7.914528   5.313208
# std     2.749633    2.147933       0.866017   0.778113   2.004899
# min     0.000000    4.550000       5.770000   6.630000   2.340000
# 25%     6.250000    7.610000       6.850000   7.320000   3.500000
# 50%     7.210000    9.700000       7.370000   7.810000   5.550000
# 75%     7.810000   10.180000       7.930000   8.340000   6.820000
# max     9.090000   13.660000       9.430000   9.980000   9.280000
#
# [8 rows x 54 columns]

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.037101 -0.332127    0.622245 -0.078678
# Arizona         NaN  0.037101  1.000000  0.271834    0.639006  0.820730
# Arkansas        NaN -0.332127  0.271834  1.000000    0.030265  0.333597
# California      NaN  0.622245  0.639006  0.030265    1.000000  0.649967
#
#             Connecticut  Delaware  District of Columbia   Florida  ...  \
# Alabama             NaN       NaN                   NaN       NaN  ...
# Alaska         0.646909  0.260265              0.271810 -0.193062  ...
# Arizona        0.555455  0.477781              0.723523  0.907295  ...
# Arkansas       0.183662  0.107639              0.433775  0.340509  ...
# California     0.881831  0.518481              0.727373  0.443946  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# Alabama           NaN       NaN                  NaN       NaN       NaN
# Alaska            NaN -0.507366             0.305388 -0.017546  0.615675
# Arizona           NaN  0.398732            -0.421255  0.413915  0.624314
# Arkansas          NaN  0.520381             0.080528  0.208586  0.236875
# California        NaN -0.109316            -0.061610  0.367924  0.894617
#
#             Virginia  Washington  West Virginia  Wisconsin   Wyoming
# Alabama          NaN         NaN            NaN        NaN       NaN
# Alaska     -0.593675    0.378141       0.056924   0.683108  0.726771
# Arizona     0.096048    0.691863       0.663311   0.014723  0.288171
# Arkansas    0.572595    0.130825       0.504703  -0.069024 -0.235369
# California -0.216247    0.816087       0.492809   0.382444  0.598739
#
# [5 rows x 54 columns]

# %%
issue_df = df[df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars']==0]

issue_df.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  Year     State  State.Minimum.Wage  \
# 0            0             0  1968   Alabama                 0.0
# 9            9             9  1968   Florida                 0.0
# 10          10            10  1968   Georgia                 0.0
# 14          14            14  1968  Illinois                 0.0
# 16          16            16  1968      Iowa                 0.0
#
#     State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                               0.0                  1.15
# 9                               0.0                  1.15
# 10                              0.0                  1.15
# 14                              0.0                  1.15
# 16                              0.0                  1.15
#
#     Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                8.55                    1.15
# 9                                8.55                    1.15
# 10                               8.55                    1.15
# 14                               8.55                    1.15
# 16                               8.55                    1.15
#
#     Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                  8.55         34.8
# 9                                  8.55         34.8
# 10                                 8.55         34.8
# 14                                 8.55         34.8
# 16                                 8.55         34.8
#
#    Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                 ...                                    0.0
# 9                                 ...                                    0.0
# 10                                ...                                    0.0
# 14                                ...                                    0.0
# 16                                ...                                    0.0
#
#     Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                 0.0
# 9                                                 0.0
# 10                                                0.0
# 14                                                0.0
# 16                                                0.0
#
#     Department.Of.Labor.Cleaned.High.Value  \
# 0                                      0.0
# 9                                      0.0
# 10                                     0.0
# 14                                     0.0
# 16                                     0.0
#
#     Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                 0.0        NaN
# 9                                                 0.0        NaN
# 10                                                0.0        NaN
# 14                                                0.0        NaN
# 16                                                0.0        NaN

# %%
issue_df['State'].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'Arizona'],
#       dtype=object)

# %%
import numpy as np

# axis 1 == columns. 0,default, is for rows
act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()
# Out:
#                         Alaska  Arkansas  California  Colorado  Connecticut  \
# Alaska                1.000000 -0.332127    0.622245 -0.078678     0.646909
# Arkansas             -0.332127  1.000000    0.030265  0.333597     0.183662
# California            0.622245  0.030265    1.000000  0.649967     0.881831
# Colorado             -0.078678  0.333597    0.649967  1.000000     0.520931
# Connecticut           0.646909  0.183662    0.881831  0.520931     1.000000
# Delaware              0.260265  0.107639    0.518481  0.581162     0.586472
# District of Columbia  0.271810  0.433775    0.727373  0.798145     0.700081
# Guam                  0.787515  0.037006    0.411729 -0.152291     0.587469
# Hawaii                0.630212  0.324870    0.610784  0.291995     0.674581
# Idaho                 0.371745  0.008276    0.542006  0.436981     0.536894
# Indiana               0.354060 -0.049715    0.736715  0.612062     0.725477
# Kentucky             -0.558293  0.441958   -0.054002  0.474155    -0.114716
# Maine                 0.642685  0.192072    0.804847  0.433139     0.715533
# Maryland              0.420479  0.555619    0.568976  0.321538     0.633147
# Massachusetts         0.618329  0.116806    0.957473  0.652008     0.901362
# Michigan              0.590455  0.213170    0.681970  0.318337     0.771777
# Minnesota            -0.363881  0.496147   -0.130918  0.091370    -0.234686
# Nebraska             -0.118830  0.291749    0.372427  0.760798     0.291186
# Nevada                0.701426 -0.054490    0.374463 -0.012322     0.534085
# New Hampshire         0.792106 -0.250984    0.350228 -0.236722     0.420869
# New Jersey            0.645369  0.111088    0.724435  0.319119     0.602805
# New Mexico            0.503251  0.159904    0.596597  0.351780     0.584606
# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1).corr()

# %%
for problem in issue_df['State'].unique():
    if problem in min_wage_corr.columns:
        print("Missing something here....")

# %%
grouped_issues = issue_df.groupby("State")

grouped_issues.get_group("Alabama").head(3)
# Out:
#      Unnamed: 0  Unnamed: 0.1  Year    State  State.Minimum.Wage  \
# 0             0             0  1968  Alabama                 0.0
# 54           54            54  1969  Alabama                 0.0
# 108         108           108  1970  Alabama                 0.0
#
#      State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.0                  1.15
# 54                               0.0                  1.15
# 108                              0.0                  1.30
#
#      Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                 8.55                    1.15
# 54                                8.11                    1.15
# 108                               8.67                    1.30
#
#      Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                                   8.55         34.8
# 54                                  8.11         36.7
# 108                                 8.67         38.8
#
#     Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                  ...                                    0.0
# 54                                 ...                                    0.0
# 108                                ...                                    0.0
#
#      Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                                  0.0
# 54                                                 0.0
# 108                                                0.0
#
#      Department.Of.Labor.Cleaned.High.Value  \
# 0                                       0.0
# 54                                      0.0
# 108                                     0.0
#
#      Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                                  0.0        NaN
# 54                                                 0.0        NaN
# 108                                                0.0        NaN

# %%
grouped_issues.get_group("Alabama")['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].sum()
# Out:
# 0.0

# %%
for state, data in grouped_issues:
    if data['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].sum() != 0.0:
        print("Some data found for", state)

# %%
min_wage_corr.head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.332127    0.622245 -0.078678     0.646909  0.260265
# Arkansas    -0.332127  1.000000    0.030265  0.333597     0.183662  0.107639
# California   0.622245  0.030265    1.000000  0.649967     0.881831  0.518481
# Colorado    -0.078678  0.333597    0.649967  1.000000     0.520931  0.581162
# Connecticut  0.646909  0.183662    0.881831  0.520931     1.000000  0.586472
#
#              District of Columbia      Guam    Hawaii     Idaho  ...  \
# Alaska                   0.271810  0.787515  0.630212  0.371745  ...
# Arkansas                 0.433775  0.037006  0.324870  0.008276  ...
# California               0.727373  0.411729  0.610784  0.542006  ...
# Colorado                 0.798145 -0.152291  0.291995  0.436981  ...
# Connecticut              0.700081  0.587469  0.674581  0.536894  ...
#
#                Oregon  Pennsylvania  Rhode Island  South Dakota      Utah  \
# Alaska       0.010495      0.590298      0.610099     -0.287259 -0.017546
# Arkansas     0.399650      0.065998      0.160773      0.826094  0.208586
# California   0.572160      0.241669      0.816544      0.171242  0.367924
# Colorado     0.733803     -0.229508      0.559646      0.519677  0.538775
# Connecticut  0.480491      0.408964      0.829952      0.228521  0.307922
#
#               Vermont  Washington  West Virginia  Wisconsin   Wyoming
# Alaska       0.615675    0.378141       0.056924   0.683108  0.726771
# Arkansas     0.236875    0.130825       0.504703  -0.069024 -0.235369
# California   0.894617    0.816087       0.492809   0.382444  0.598739
# Colorado     0.581318    0.721208       0.623479  -0.101133  0.095454
# Connecticut  0.911003    0.760697       0.484080   0.468287  0.752009
#
# [5 rows x 37 columns]

# %%
import matplotlib.pyplot as plt

labels = [c[:2] for c in min_wage_corr.columns]  # get abbv state names.

fig = plt.figure(figsize=(12,12))  # figure so we can add axis

ax = fig.add_subplot(111)  # define axis, so we can modify

ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix

ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!

ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()

# %%
# pip install lxml html5lib bs4
# on mac, run: /Applications/Python\ 3.7/Install\ Certificates.command


import requests

web = requests.get("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")
dfs = pd.read_html(web.text)


import pandas as pd

# https://www.infoplease.com/state-abbreviations-and-state-postal-codes

dfs = pd.read_html("https://www.infoplease.com/state-abbreviations-and-state-postal-codes")

# %%
for df in dfs:
    print(df.head())  # one is states, the other territory
# Out:
#   State Name/District Postal Abbreviation Postal Code
# 0             Alabama                Ala.          AL
# 1              Alaska              Alaska          AK
# 2             Arizona               Ariz.          AZ
# 3            Arkansas                Ark.          AR
# 4          California              Calif.          CA
#         Territory/Associate Abbreviation Postal Code
# 0            American Samoa          NaN          AS
# 1                      Guam         Guam          GU
# 2          Marshall Islands          NaN          MH
# 3                Micronesia          NaN          FM
# 4  Northern Mariana Islands          NaN          MP

# %%
state_abbv = dfs[0]

state_abbv.head()
# Out:
#   State Name/District Postal Abbreviation Postal Code
# 0             Alabama                Ala.          AL
# 1              Alaska              Alaska          AK
# 2             Arizona               Ariz.          AZ
# 3            Arkansas                Ark.          AR
# 4          California              Calif.          CA

# %%
state_abbv.to_csv("state_abbv.csv")

# %%
state_abbv = pd.read_csv("state_abbv.csv")
state_abbv.head()
# Out:
#    Unnamed: 0 State Name/District Postal Abbreviation Postal Code
# 0           0             Alabama                Ala.          AL
# 1           1              Alaska              Alaska          AK
# 2           2             Arizona               Ariz.          AZ
# 3           3            Arkansas                Ark.          AR
# 4           4          California              Calif.          CA

# %%
state_abbv[["State Name/District", "Postal Code"]].to_csv("state_abbv.csv", index=False)  # index in this case is worthless

# %%
state_abbv = pd.read_csv("state_abbv.csv", index_col=0)
state_abbv.head()
# Out:
#                     Postal Code
# State Name/District
# Alabama                      AL
# Alaska                       AK
# Arizona                      AZ
# Arkansas                     AR
# California                   CA

# %%
abbv_dict = state_abbv.to_dict()

# %%
abbv_dict
# Out:
# {'Postal Code': {'Alabama': 'AL',
#   'Alaska': 'AK',
#   'Arizona': 'AZ',
#   'Arkansas': 'AR',
#   'California': 'CA',
#   'Colorado': 'CO',
#   'Connecticut': 'CT',
#   'Delaware': 'DE',
#   'District of Columbia': 'DC',
#   'Florida': 'FL',
#   'Georgia': 'GA',
#   'Hawaii': 'HI',
#   'Idaho': 'ID',
#   'Illinois': 'IL',
#   'Indiana': 'IN',
#   'Iowa': 'IA',
#   'Kansas': 'KS',
#   'Kentucky': 'KY',
#   'Louisiana': 'LA',
#   'Maine': 'ME',
#   'Maryland': 'MD',
#   'Massachusetts': 'MA',
#   'Michigan': 'MI',
#   'Minnesota': 'MN',
#   'Mississippi': 'MS',
#   'Missouri': 'MO',
#   'Montana': 'MT',
#   'Nebraska': 'NE',
#   'Nevada': 'NV',
#   'New Hampshire': 'NH',
#   'New Jersey': 'NJ',
#   'New Mexico': 'NM',
#   'New York': 'NY',
#   'North Carolina': 'NC',
#   'North Dakota': 'ND',
#   'Ohio': 'OH',
#   'Oklahoma': 'OK',
#   'Oregon': 'OR',
#   'Pennsylvania': 'PA',
#   'Rhode Island': 'RI',
#   'South Carolina': 'SC',
#   'South Dakota': 'SD',
#   'Tennessee': 'TN',
#   'Texas': 'TX',
#   'Utah': 'UT',
#   'Vermont': 'VT',
#   'Virginia': 'VA',
#   'Washington': 'WA',
#   'West Virginia': 'WV',
#   'Wisconsin': 'WI',
#   'Wyoming': 'WY'}}

# %%
abbv_dict = abbv_dict['Postal Code']
abbv_dict
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
abbv_dict['Guam'] = "GU"
abbv_dict['Puerto Rico'] = "PR"
labels = [abbv_dict[c] for c in min_wage_corr.columns]  # get abbv state names.

# %%
fig = plt.figure(figsize=(12,12))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(min_wage_corr, cmap=plt.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plt.show()
